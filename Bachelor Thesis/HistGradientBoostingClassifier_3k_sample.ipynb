# %%
#imports
import pandas as pd
import numpy as np
from scipy.stats import pearsonr
import random as rd

# remove warnings
import warnings
warnings.simplefilter(action='ignore')

# seed fixation
np.random.seed(34)

# %% [markdown]
# ### Import of ESS dataset

# %%
ess = pd.read_csv('ESS9e03_1.csv', low_memory = False)

# %%
ess.head(20)
# Out:
#          name  essround  edition    proddate  idno cntry   dweight   pspwght  \
# 0   ESS9e03_1         9      3.1  17.02.2021    27    AT  0.581174  0.218111
# 1   ESS9e03_1         9      3.1  17.02.2021   137    AT  1.062772  0.413473
# 2   ESS9e03_1         9      3.1  17.02.2021   194    AT  1.376509  2.270293
# 3   ESS9e03_1         9      3.1  17.02.2021   208    AT  0.993399  0.386483
# 4   ESS9e03_1         9      3.1  17.02.2021   220    AT  0.377353  1.032102
# 5   ESS9e03_1         9      3.1  17.02.2021   254    AT  1.479353  0.575545
# 6   ESS9e03_1         9      3.1  17.02.2021   290    AT  0.991758  0.720604
# 7   ESS9e03_1         9      3.1  17.02.2021   301    AT  0.309859  0.130113
# 8   ESS9e03_1         9      3.1  17.02.2021   305    AT  1.230384  1.770760
# 9   ESS9e03_1         9      3.1  17.02.2021   400    AT  0.458836  0.742814
# 10  ESS9e03_1         9      3.1  17.02.2021   413    AT  0.426158  0.159935
# 11  ESS9e03_1         9      3.1  17.02.2021   438    AT  0.991758  0.777761
# 12  ESS9e03_1         9      3.1  17.02.2021   459    AT  1.106135  0.803710
# 13  ESS9e03_1         9      3.1  17.02.2021   472    AT  0.820256  0.983047
# 14  ESS9e03_1         9      3.1  17.02.2021   586    AT  0.471760  0.342778
# 15  ESS9e03_1         9      3.1  17.02.2021   592    AT  0.573064  1.020268
# 16  ESS9e03_1         9      3.1  17.02.2021   614    AT  0.929577  0.361653
# 17  ESS9e03_1         9      3.1  17.02.2021   651    AT  1.312880  0.551292
# 18  ESS9e03_1         9      3.1  17.02.2021   687    AT  0.309859  0.116288
# 19  ESS9e03_1         9      3.1  17.02.2021   703    AT  0.552110  1.389067
#
#      pweight  anweight  ...  inwyys  inwshh  inwsmm  inwdde  inwmme  inwyye  \
# 0   0.302091  0.065890  ...    2018    20.0    19.0     2.0      12    2018
# 1   0.302091  0.124907  ...    2018     9.0    39.0    19.0      12    2018
# 2   0.302091  0.685836  ...    2018    19.0    13.0    12.0      11    2018
# 3   0.302091  0.116753  ...    2018    16.0    31.0    26.0      11    2018
# 4   0.302091  0.311789  ...    2018    13.0    53.0     5.0      12    2018
# 5   0.302091  0.173867  ...    2018    16.0    14.0     3.0      12    2018
# 6   0.302091  0.217688  ...    2018    14.0    39.0    29.0       9    2018
# 7   0.302091  0.039306  ...    2018    17.0    45.0     9.0      11    2018
# 8   0.302091  0.534931  ...    2018    16.0    19.0    10.0      10    2018
# 9   0.302091  0.224398  ...    2018    12.0    27.0    27.0      10    2018
# 10  0.302091  0.048315  ...    2018    13.0     8.0     8.0      12    2018
# 11  0.302091  0.234955  ...    2018     9.0    20.0    18.0      12    2018
# 12  0.302091  0.242794  ...    2018    12.0    48.0    24.0       9    2018
# 13  0.302091  0.296970  ...    2018    11.0    14.0    16.0      11    2018
# 14  0.302091  0.103550  ...    2018    13.0    41.0    30.0      12    2018
# 15  0.302091  0.308214  ...    2018    14.0    46.0    10.0      11    2018
# 16  0.302091  0.109252  ...    2018    12.0    37.0    30.0       9    2018
# 17  0.302091  0.166540  ...    2018    14.0    28.0    19.0      11    2018
# 18  0.302091  0.035130  ...    2018    13.0     1.0    26.0       9    2018
# 19  0.302091  0.419625  ...    2018    19.0    35.0     6.0      12    2018
#
#     inwehh  inwemm  inwtm  domain
# 0     21.0     7.0   46.0     2.0
# 1     11.0     6.0   73.0     2.0
# 2     20.0    48.0   92.0     2.0
# 3     18.0    49.0  134.0     2.0
# 4     14.0    39.0   40.0     2.0
# 5     17.0    12.0   52.0     2.0
# 6     15.0    57.0   75.0     2.0
# 7     18.0    56.0   67.0     2.0
# 8     17.0    11.0   32.0     2.0
# 9     13.0    48.0   75.0     2.0
# 10    14.0    51.0   89.0     2.0
# 11    11.0    14.0  102.0     2.0
# 12    13.0    52.0   58.0     1.0
# 13    11.0    55.0   32.0     2.0
# 14    14.0    36.0   55.0     2.0
# 15    15.0    36.0   44.0     2.0
# 16    14.0     0.0   78.0     2.0
# 17    15.0    33.0   59.0     2.0
# 18    14.0     5.0   59.0     2.0
# 19    20.0    47.0   65.0     1.0
#
# [20 rows x 572 columns]

# %% [markdown]
# #### Selecting only France

# %%
france = ess[ess['cntry'] == 'FR']
france
# Out:
#             name  essround  edition    proddate   idno cntry   dweight  \
# 20442  ESS9e03_1         9      3.1  17.02.2021     23    FR  1.119029
# 20443  ESS9e03_1         9      3.1  17.02.2021     41    FR  0.537166
# 20444  ESS9e03_1         9      3.1  17.02.2021     53    FR  1.712321
# 20445  ESS9e03_1         9      3.1  17.02.2021     83    FR  1.036066
# 20446  ESS9e03_1         9      3.1  17.02.2021     98    FR  0.566907
# ...          ...       ...      ...         ...    ...   ...       ...
# 22447  ESS9e03_1         9      3.1  17.02.2021  69851    FR  1.677517
# 22448  ESS9e03_1         9      3.1  17.02.2021  69860    FR  0.571441
# 22449  ESS9e03_1         9      3.1  17.02.2021  69952    FR  1.131332
# 22450  ESS9e03_1         9      3.1  17.02.2021  69962    FR  0.527490
# 22451  ESS9e03_1         9      3.1  17.02.2021  69965    FR  1.124576
#
#         pspwght   pweight   anweight  ...  inwyys  inwshh  inwsmm  inwdde  \
# 20442  0.914294  2.726687   2.492995  ...    2018    16.0     1.0    20.0
# 20443  0.741584  2.726687   2.022066  ...    2019    13.0    59.0     6.0
# 20444  1.218063  2.726687   3.321277  ...    2019     9.0    22.0     7.0
# 20445  0.925803  2.726687   2.524374  ...    2019    15.0    30.0     8.0
# 20446  2.774719  2.726687   7.565790  ...    2018     9.0     0.0    21.0
# ...         ...       ...        ...  ...     ...     ...     ...     ...
# 22447  1.472812  2.726687   4.015897  ...    2019     9.0    57.0    23.0
# 22448  0.553700  2.726687   1.509766  ...    2018    13.0    33.0    17.0
# 22449  3.999952  2.726687  10.906615  ...    2019    16.0    47.0    11.0
# 22450  0.492084  2.726687   1.341760  ...    2018    10.0    39.0     4.0
# 22451  4.000000  2.726687  10.906748  ...    2019    13.0    48.0    16.0
#
#        inwmme  inwyye  inwehh  inwemm  inwtm  domain
# 20442      12    2018    17.0    11.0   70.0     2.0
# 20443       2    2019    14.0    51.0   52.0     1.0
# 20444       1    2019    10.0    28.0   66.0     2.0
# 20445       1    2019    16.0    40.0   70.0     1.0
# 20446      11    2018     9.0    59.0   59.0     2.0
# ...       ...     ...     ...     ...    ...     ...
# 22447       1    2019    10.0    38.0   41.0     2.0
# 22448      12    2018    15.0     6.0   93.0     2.0
# 22449       1    2019    17.0    54.0   67.0     2.0
# 22450      12    2018    10.0    49.0   10.0     1.0
# 22451       2    2019    14.0    35.0   47.0     2.0
#
# [2010 rows x 572 columns]

# %% [markdown]
# #### Droping Nans

# %%
fr_ess = france[['netusoft', 'polintr', 'trstprt', 'stflife', 'stfeco', 'sclmeet', 'agea']]
fr_ess = fr_ess[(fr_ess['netusoft'] != 7) & (fr_ess['netusoft'] != 8) & (fr_ess['netusoft']!=9)]
fr_ess = fr_ess[(fr_ess['trstprt'] != 77) & (fr_ess['trstprt'] != 88) & (fr_ess['trstprt'] !=99)]
fr_ess = fr_ess[(fr_ess['stflife'] != 77) & (fr_ess['stflife'] != 88) & (fr_ess['stflife'] !=99)]
fr_ess = fr_ess[(fr_ess['stfeco'] != 77) & (fr_ess['stfeco'] != 88) & (fr_ess['stfeco'] !=99)]
fr_ess = fr_ess[(fr_ess['sclmeet'] != 77) & (fr_ess['sclmeet'] != 88) & (fr_ess['sclmeet'] !=99)]
fr_ess = fr_ess[(fr_ess['agea'] != 999)]
fr_ess
# Out:
#        netusoft  polintr  trstprt  stflife  stfeco  sclmeet  agea
# 20442         3        1        2        6       3        6    72
# 20443         5        3        5        9       5        7    30
# 20444         5        1        1        6       0        6    77
# 20445         5        4        0        7       0        3    24
# 20446         1        4        3        3       3        2    50
# ...         ...      ...      ...      ...     ...      ...   ...
# 22446         5        3        0        0       0        6    77
# 22447         5        3        3        4       3        7    43
# 22448         2        3        3        6       2        6    71
# 22449         5        3        4        3       2        5    45
# 22451         4        4        0        8       5        6    51
#
# [1919 rows x 7 columns]

# %% [markdown]
# ### Generation of MCAR missing data

# %%
empty_list = []
random_list = [rd.randint(1, 1900) for _ in range(1000)] # for random choosing data
for n in random_list:
    item = fr_ess.iloc[n:n+10,:] # making the slices
    mask = np.random.choice([True, False], size=tuple([len(item), 1])) # mask for column with missings
    matrix = np.full((len(item), item.shape[1] - 1), False)

    number = rd.randint(1, 7)
    matrix_new = np.concatenate((matrix[:, :number], mask, matrix[:, number:]), axis=1)  # mask for full data slice

    MCAR_matrix = item.mask(matrix_new) # making MCAR missing data
    empty_list.append([MCAR_matrix.to_numpy(), matrix_new])

# %%
result_1 = pd.DataFrame(empty_list, columns = ['Xobs', 'Xmis'])
result_1
# Out:
#                                                   Xobs  \
# 0    [[5.0, 4.0, 4.0, 7.0, 6.0, 6.0, 48.0], [5.0, 1...
# 1    [[5.0, 3.0, 3.0, 8.0, 4.0, 6.0, 27.0], [3.0, 3...
# 2    [[5.0, 3.0, 6.0, 4.0, 4.0, 6.0, 19.0], [3.0, 4...
# 3    [[5.0, 1.0, 1.0, 3.0, 1.0, 6.0, 45.0], [4.0, 2...
# 4    [[5.0, 3.0, 0.0, 10.0, nan, 6.0, 84.0], [5.0, ...
# ..                                                 ...
# 995  [[4.0, 2.0, 3.0, nan, 3.0, 4.0, 66.0], [5.0, 4...
# 996  [[5.0, 2.0, 4.0, 8.0, 7.0, 4.0, 21.0], [5.0, 1...
# 997  [[3.0, 2.0, 3.0, 7.0, 5.0, 4.0, 57.0], [2.0, 4...
# 998  [[3.0, 2.0, 7.0, 8.0, 7.0, 6.0, nan], [1.0, 2....
# 999  [[5.0, 1.0, 5.0, 4.0, 4.0, nan, 39.0], [5.0, 3...
#
#                                                   Xmis
# 0    [[False, False, False, False, False, False, Fa...
# 1    [[False, False, False, False, False, False, Fa...
# 2    [[False, False, False, False, False, False, Fa...
# 3    [[False, False, False, False, False, False, Fa...
# 4    [[False, False, False, False, True, False, Fal...
# ..                                                 ...
# 995  [[False, False, False, True, False, False, Fal...
# 996  [[False, False, False, False, False, False, Fa...
# 997  [[False, False, False, False, False, False, Fa...
# 998  [[False, False, False, False, False, False, Tr...
# 999  [[False, False, False, False, False, True, Fal...
#
# [1000 rows x 2 columns]

# %%
result_1['MDM'] = 0 #MCAR => 0
result_1
# Out:
#                                                   Xobs  \
# 0    [[5.0, 4.0, 4.0, 7.0, 6.0, 6.0, 48.0], [5.0, 1...
# 1    [[5.0, 3.0, 3.0, 8.0, 4.0, 6.0, 27.0], [3.0, 3...
# 2    [[5.0, 3.0, 6.0, 4.0, 4.0, 6.0, 19.0], [3.0, 4...
# 3    [[5.0, 1.0, 1.0, 3.0, 1.0, 6.0, 45.0], [4.0, 2...
# 4    [[5.0, 3.0, 0.0, 10.0, nan, 6.0, 84.0], [5.0, ...
# ..                                                 ...
# 995  [[4.0, 2.0, 3.0, nan, 3.0, 4.0, 66.0], [5.0, 4...
# 996  [[5.0, 2.0, 4.0, 8.0, 7.0, 4.0, 21.0], [5.0, 1...
# 997  [[3.0, 2.0, 3.0, 7.0, 5.0, 4.0, 57.0], [2.0, 4...
# 998  [[3.0, 2.0, 7.0, 8.0, 7.0, 6.0, nan], [1.0, 2....
# 999  [[5.0, 1.0, 5.0, 4.0, 4.0, nan, 39.0], [5.0, 3...
#
#                                                   Xmis  MDM
# 0    [[False, False, False, False, False, False, Fa...    0
# 1    [[False, False, False, False, False, False, Fa...    0
# 2    [[False, False, False, False, False, False, Fa...    0
# 3    [[False, False, False, False, False, False, Fa...    0
# 4    [[False, False, False, False, True, False, Fal...    0
# ..                                                 ...  ...
# 995  [[False, False, False, True, False, False, Fal...    0
# 996  [[False, False, False, False, False, False, Fa...    0
# 997  [[False, False, False, False, False, False, Fa...    0
# 998  [[False, False, False, False, False, False, Tr...    0
# 999  [[False, False, False, False, False, True, Fal...    0
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### Generation of MAR missing data

# %%
empty_list = []
counter = 0
random_list = [rd.randint(1, 1900) for _ in range(1000)] #list for subsampling from dataset
for n in random_list:
    item = fr_ess.iloc[n:n+10,:]
    m = rd.randint(0, 6) #random chosing for a column on which will depend missing data

    lst = list(fr_ess.iloc[n:n+10,:].iloc[:, m].unique())
    if len(lst) > 4:
        lst_for_threshold = sorted(lst)[1:-1]
    else:
        lst_for_threshold = sorted(lst)

    threshold = rd.choice(lst_for_threshold) #chosing the threshold for missing data
    probability_missing = [0.8, 0.9, 1.0]  #probabilities for data being missed

    if counter%2 == 0: #changing of > and < sign
        item['MissingProbability'] = np.where(item.iloc[:, m] > threshold, rd.choice(probability_missing), 0)
        item['MissingProbability_2'] = np.where(item.iloc[:, m] > threshold, 1 - item['MissingProbability'], 1 - item['MissingProbability'])
        item['MissingProbability_3'] = item.apply(lambda row: tuple([row['MissingProbability'], row['MissingProbability_2']]), axis=1)
    else:
        item['MissingProbability'] = np.where(item.iloc[:, m] < threshold, rd.choice(probability_missing), 0)
        item['MissingProbability_2'] = np.where(item.iloc[:, m] < threshold, 1 - item['MissingProbability'], 1 - item['MissingProbability'])
        item['MissingProbability_3'] = item.apply(lambda row: tuple([row['MissingProbability'], row['MissingProbability_2']]), axis=1)

    item['new'] = item['MissingProbability_3'].apply(lambda row: rd.choices([True, False], weights=row, k=1)[0])
    number = rd.randint(1, 6) #chose a number for a column with missings
    while m == number: #check the inequality of number of column with missings and the column which determines the probability of missed data
        number = rd.randint(1, 6)
    matrix = np.full((len(item), item.shape[1] - 5), False)
    matrix_new = np.concatenate((matrix[:, :number], item[['new']], matrix[:, number:]), axis=1)
    item.iloc[:, number] = np.where(item['new'].to_numpy(), np.nan, item.iloc[:, number])
    MAR_matrix = item.drop(columns=['MissingProbability', 'MissingProbability_2', 'MissingProbability_3', 'new'])

    empty_list.append([MAR_matrix.to_numpy(), matrix_new])

# %%
result_2 = pd.DataFrame(empty_list, columns = ['Xobs', 'Xmis'])
result_2['MDM'] = 1  #MAR => 1
result_2
# Out:
#                                                   Xobs  \
# 0    [[5.0, 4.0, 5.0, 8.0, 5.0, 4.0, 35.0], [4.0, 2...
# 1    [[1.0, 3.0, 5.0, 8.0, 5.0, 5.0, nan], [5.0, 1....
# 2    [[5.0, 2.0, 2.0, 5.0, 1.0, 4.0, 66.0], [5.0, 1...
# 3    [[5.0, 1.0, 4.0, 8.0, 3.0, 4.0, 36.0], [5.0, 1...
# 4    [[5.0, 2.0, 5.0, 7.0, 5.0, 5.0, 66.0], [1.0, 2...
# ..                                                 ...
# 995  [[3.0, 3.0, 2.0, 6.0, 4.0, 4.0, 41.0], [5.0, n...
# 996  [[5.0, 4.0, 4.0, 9.0, 6.0, 7.0, nan], [5.0, 4....
# 997  [[2.0, 3.0, 1.0, 9.0, 2.0, 6.0, 62.0], [5.0, 1...
# 998  [[5.0, 3.0, 0.0, 4.0, 4.0, 6.0, 24.0], [1.0, 2...
# 999  [[5.0, 2.0, 4.0, 5.0, 3.0, nan, 69.0], [4.0, 2...
#
#                                                   Xmis  MDM
# 0    [[False, False, False, False, False, False, Fa...    1
# 1    [[False, False, False, False, False, False, Tr...    1
# 2    [[False, False, False, False, False, False, Fa...    1
# 3    [[False, False, False, False, False, False, Fa...    1
# 4    [[False, False, False, False, False, False, Fa...    1
# ..                                                 ...  ...
# 995  [[False, False, False, False, False, False, Fa...    1
# 996  [[False, False, False, False, False, False, Tr...    1
# 997  [[False, False, False, False, False, False, Fa...    1
# 998  [[False, False, False, False, False, False, Fa...    1
# 999  [[False, False, False, False, False, True, Fal...    1
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### Generation of MNAR missing data

# %%
empty_list = []
counter = 0
random_list = [rd.randint(1, 1900) for _ in range(1000)] #list for subsampling from dataset
for n in random_list:
    item = fr_ess.iloc[n:n+10,:]
    m = rd.randint(1, 6) #random chosing for a column with missing

    #manipulations for threshold
    lst = list(fr_ess.iloc[n:n+10,:].iloc[:, m].unique())
    if len(lst) > 4:
        lst_for_threshold = sorted(lst)[1:-1]
    else:
        lst_for_threshold = sorted(lst)

    threshold = rd.choice(lst_for_threshold) #chosing the threshold for missing data
    probability_missing = [0.8, 0.9, 1.0]  #probabilities for data being missed

    if counter%2 == 0: #changing of > and < sign
        item['MissingProbability'] = np.where(item.iloc[:, m] > threshold, rd.choice(probability_missing), 0)
        item['MissingProbability_2'] = np.where(item.iloc[:, m] > threshold, 1 - item['MissingProbability'], 1 - item['MissingProbability'])
        item['MissingProbability_3'] = item.apply(lambda row: tuple([row['MissingProbability'], row['MissingProbability_2']]), axis=1)
    else:
        item['MissingProbability'] = np.where(item.iloc[:, m] < threshold, rd.choice(probability_missing), 0)
        item['MissingProbability_2'] = np.where(item.iloc[:, m] < threshold, 1 - item['MissingProbability'], 1 - item['MissingProbability'])
        item['MissingProbability_3'] = item.apply(lambda row: tuple([row['MissingProbability'], row['MissingProbability_2']]), axis=1)

    item['new'] = item['MissingProbability_3'].apply(lambda row: rd.choices([True, False], weights=row, k=1)[0])

    number = m  #as well as the column with missings depends on itself

    matrix = np.full((len(item), item.shape[1] - 5), False)
    matrix_new = np.concatenate((matrix[:, :number], item[['new']], matrix[:, number:]), axis=1)

    item.iloc[:, number] = np.where(item['new'].to_numpy(), np.nan, item.iloc[:, number])

    MAR_matrix = item.drop(columns=['MissingProbability', 'MissingProbability_2', 'MissingProbability_3', 'new'])

    empty_list.append([MAR_matrix.to_numpy(), matrix_new])

# %%
result_3 = pd.DataFrame(empty_list, columns = ['Xobs', 'Xmis'])
result_3['MDM'] = 2  #MNAR => 2
result_3
# Out:
#                                                   Xobs  \
# 0    [[5.0, 2.0, 2.0, 6.0, 2.0, 7.0, 41.0], [5.0, n...
# 1    [[4.0, 3.0, 4.0, 5.0, 1.0, 7.0, 53.0], [2.0, 1...
# 2    [[1.0, 4.0, 0.0, 8.0, 2.0, 3.0, 80.0], [5.0, 3...
# 3    [[5.0, 1.0, 3.0, 9.0, 6.0, 5.0, 32.0], [5.0, n...
# 4    [[1.0, 2.0, 5.0, 8.0, 5.0, 4.0, 83.0], [5.0, 2...
# ..                                                 ...
# 995  [[5.0, 3.0, 4.0, 5.0, 4.0, 3.0, 57.0], [5.0, 1...
# 996  [[5.0, 2.0, 3.0, 10.0, 6.0, 7.0, 60.0], [5.0, ...
# 997  [[5.0, 4.0, 1.0, 2.0, 0.0, 3.0, 57.0], [2.0, 2...
# 998  [[5.0, 1.0, 5.0, nan, 5.0, 6.0, 66.0], [4.0, 4...
# 999  [[3.0, 4.0, 1.0, 5.0, 0.0, 4.0, 57.0], [5.0, 3...
#
#                                                   Xmis  MDM
# 0    [[False, False, False, False, False, False, Fa...    2
# 1    [[False, False, False, False, False, False, Fa...    2
# 2    [[False, False, False, False, False, False, Fa...    2
# 3    [[False, False, False, False, False, False, Fa...    2
# 4    [[False, False, False, False, False, False, Fa...    2
# ..                                                 ...  ...
# 995  [[False, False, False, False, False, False, Fa...    2
# 996  [[False, False, False, False, False, False, Fa...    2
# 997  [[False, False, False, False, False, False, Fa...    2
# 998  [[False, False, False, True, False, False, Fal...    2
# 999  [[False, False, False, False, False, False, Fa...    2
#
# [1000 rows x 3 columns]

# %% [markdown]
# ### The concatenated dataframe with final training dataset

# %%
cnct_df = pd.concat([result_1, result_2, result_3]).reset_index()
cnct_df
# Out:
#       index                                               Xobs  \
# 0         0  [[5.0, 4.0, 4.0, 7.0, 6.0, 6.0, 48.0], [5.0, 1...
# 1         1  [[5.0, 3.0, 3.0, 8.0, 4.0, 6.0, 27.0], [3.0, 3...
# 2         2  [[5.0, 3.0, 6.0, 4.0, 4.0, 6.0, 19.0], [3.0, 4...
# 3         3  [[5.0, 1.0, 1.0, 3.0, 1.0, 6.0, 45.0], [4.0, 2...
# 4         4  [[5.0, 3.0, 0.0, 10.0, nan, 6.0, 84.0], [5.0, ...
# ...     ...                                                ...
# 2995    995  [[5.0, 3.0, 4.0, 5.0, 4.0, 3.0, 57.0], [5.0, 1...
# 2996    996  [[5.0, 2.0, 3.0, 10.0, 6.0, 7.0, 60.0], [5.0, ...
# 2997    997  [[5.0, 4.0, 1.0, 2.0, 0.0, 3.0, 57.0], [2.0, 2...
# 2998    998  [[5.0, 1.0, 5.0, nan, 5.0, 6.0, 66.0], [4.0, 4...
# 2999    999  [[3.0, 4.0, 1.0, 5.0, 0.0, 4.0, 57.0], [5.0, 3...
#
#                                                    Xmis  MDM
# 0     [[False, False, False, False, False, False, Fa...    0
# 1     [[False, False, False, False, False, False, Fa...    0
# 2     [[False, False, False, False, False, False, Fa...    0
# 3     [[False, False, False, False, False, False, Fa...    0
# 4     [[False, False, False, False, True, False, Fal...    0
# ...                                                 ...  ...
# 2995  [[False, False, False, False, False, False, Fa...    2
# 2996  [[False, False, False, False, False, False, Fa...    2
# 2997  [[False, False, False, False, False, False, Fa...    2
# 2998  [[False, False, False, True, False, False, Fal...    2
# 2999  [[False, False, False, False, False, False, Fa...    2
#
# [3000 rows x 4 columns]

# %% [markdown]
# ### Step 1. HistGradientBoostingClassifier

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score


X = cnct_df['Xobs']
y = cnct_df['MDM']
X = [arr.ravel() for arr in X]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle = True, random_state = 34)

# model
clf = HistGradientBoostingClassifier(l2_regularization = 1.5, learning_rate = 0.01, random_state=34)
# train the model
clf.fit(X_train, y_train)
# predictions
y_pred = clf.predict(X_test)

# Model quality
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.3877777777777778

# %% [markdown]
# #### Confusion matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

y_pred = clf.predict(X_test)
# Model quality
conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %% [markdown]
# #### Changing the hyperparameter learning rate

# %%
X = cnct_df['Xobs']
y = cnct_df['MDM']

X = [arr.ravel() for arr in X]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state = 34)

learning_rates = [0.001, 0.01, 0.1, 0.5]

for lr in learning_rates:
    clf = HistGradientBoostingClassifier(l2_regularization=1.5, learning_rate=lr, random_state = 34)
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)

    # Model quality
    accuracy = accuracy_score(y_test, y_pred)
    print(f"Learning Rate: {lr} - Accuracy: {accuracy}")
# Out:
# Learning Rate: 0.001 - Accuracy: 0.37333333333333335
# Learning Rate: 0.01 - Accuracy: 0.3877777777777778
# Learning Rate: 0.1 - Accuracy: 0.4033333333333333
# Learning Rate: 0.5 - Accuracy: 0.4077777777777778

# %% [markdown]
# #### For the last model with lr = 0.5 confusion matrix

# %%
conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
